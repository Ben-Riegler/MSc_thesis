# %%
import torch
import stheno

from convcnp.architectures import SimpleConv, UNet
from convcnp.set_conv import ConvCNP
from convcnp.utils import device
import convcnp.data

from eval_fcts import plot_model_task

# %%
model_sin = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=SimpleConv())

path_sin = "experiments/convcnp-sin/checkpoint.pth.tar"
load_dict = torch.load(path_sin)
model_sin.load_state_dict(load_dict['state_dict'])
model_sin.to(device)
# Out:
# /tmp/ipykernel_3835563/992646078.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_sin)

# %%
model_sawtooth = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=SimpleConv())

path_sawtooth = "experiments/convcnp-sawtooth/model_best.pth.tar"
load_dict = torch.load(path_sawtooth)
model_sawtooth.load_state_dict(load_dict['state_dict'])
model_sawtooth.to(device)

n_ctxt = 10
ctxt_ran = (0,6)

gen = convcnp.data.SawtoothGenerator(x_range = ctxt_ran)
task = gen.generate_task(n_ctxt = n_ctxt)
# Out:
# /tmp/ipykernel_327212/568889551.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_sawtooth)

# %%
task["y"].shape
# Out:
# torch.Size([16, 30, 1])

# %%
idx = 11
pred_ran = (-2,6)
plot_model_task(model_sawtooth, task, idx, pred_ran, True)

# %%
model_sawtoothxl = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=UNet())

path_sawtoothxl = "experiments/convcnpxl-sawtooth/model_best.pth.tar"
load_dict = torch.load(path_sawtoothxl)
model_sawtoothxl.load_state_dict(load_dict['state_dict'])
model_sawtoothxl.to(device)

n_ctxt = 50
ctxt_ran = (-2,2)

gen = convcnp.data.SawtoothGenerator(x_range = ctxt_ran)
task = gen.generate_task(n_ctxt = n_ctxt)
# Out:
# /tmp/ipykernel_3835563/1882214767.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_sawtoothxl)

# %%
idx = 15
pred_ran = (-4,4)
plot_model_task(model_sawtoothxl, task, idx, pred_ran, True)

# %%
model_eq = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=SimpleConv())

path_eq = "experiments/convcnp-eq/checkpoint.pth.tar"
load_dict = torch.load(path_eq)
model_eq.load_state_dict(load_dict['state_dict'])
model_eq.to(device)

n_ctxt = 10
ctxt_ran = (-2,2)

gen = convcnp.data.GPGenerator(x_range = ctxt_ran, kernel=stheno.EQ().stretch(0.25))
task = gen.generate_task(n_ctxt = n_ctxt)
# Out:
# /tmp/ipykernel_291967/2765306207.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_eq)

# %%
idx = 12
pred_ran = (-4,4)
plot_model_task(model_eq, task, idx, pred_ran)

# %%
model_mat = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=SimpleConv())

path_mat = "experiments/convcnp-matern/checkpoint.pth.tar"
load_dict = torch.load(path_mat)
model_mat.load_state_dict(load_dict['state_dict'])
model_mat.to(device)

n_ctxt = 10
ctxt_ran = (-2,2)

gen = convcnp.data.GPGenerator(x_range = ctxt_ran, kernel=stheno.Matern52().stretch(0.25))
task = gen.generate_task(n_ctxt = n_ctxt)
# Out:
# /tmp/ipykernel_291967/1192310071.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_mat)

# %%
idx = 12
pred_ran = (-4,4)
plot_model_task(model_mat, task, idx, pred_ran)

# %% [markdown]
# Fix data generators!

# %%
# %%capture
model_eq = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=UNet())

path_eq = "experiments/convcnpxl-eq/checkpoint.pth.tar"
load_dict = torch.load(path_eq)
model_eq.load_state_dict(load_dict['state_dict'])
model_eq.to(device)
# Out:
# /tmp/ipykernel_291967/2612218189.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_eq)

# %%
for i in range(16):


    n_ctxt = 1+i
    ctxt_ran = (-2,2)

    gen = convcnp.data.GPGenerator(x_range = ctxt_ran, kernel=stheno.EQ().stretch(0.25))
    task = gen.generate_task(n_ctxt = n_ctxt)

    idx = i
    
    if (i % 2 == 0): pred_ran = (-2,2) 
    
    else: pred_ran = (-4,4)

    plot_model_task(model_eq, task, idx, pred_ran, save = i, name = "eq")

# %%
# %%capture
model_mat = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=UNet())

path_mat = "experiments/convcnpxl-matern/checkpoint.pth.tar"
load_dict = torch.load(path_mat)
model_mat.load_state_dict(load_dict['state_dict'])
model_mat.to(device)
# Out:
# /tmp/ipykernel_291967/3736985385.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_dict = torch.load(path_mat)

# %%
for i in range(16):


    n_ctxt = 1+i
    ctxt_ran = (-2,2)

    gen = convcnp.data.GPGenerator(x_range = ctxt_ran, kernel=stheno.Matern52().stretch(0.25))
    task = gen.generate_task(n_ctxt = n_ctxt)

    idx = i
    
    if (i % 2 == 0): pred_ran = (-2,2) 
    
    else: pred_ran = (-4,4)

    plot_model_task(model_mat, task, idx, pred_ran, save = i, name = "mat")

# %%
# %%capture
model_sinxl = ConvCNP(learn_length_scale=True,
                points_per_unit=64,
                architecture=UNet())

path_sinxl = "experiments/convcnpxl-sin/checkpoint.pth.tar"
load_dict = torch.load(path_sinxl)
model_sinxl.load_state_dict(load_dict['state_dict'])
model_sinxl.to(device)

# %%
for i in range(16):

    n_ctxt = 1+i
    ctxt_ran = (-2,2)

    gen = convcnp.data.SinGenerator(x_range = ctxt_ran)
    task = gen.generate_task(n_ctxt = n_ctxt)

    idx = i
    
    if (i % 2 == 0): pred_ran = (-2,2) 
    
    else: pred_ran = (-4,4)

    plot_model_task(model_sinxl, task, idx, pred_ran, save = i, name = "sin")
